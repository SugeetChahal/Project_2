# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
DV_crime_df = pd.read_csv("../Violence_data/DV_crime.csv")
DV_crime_df.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2018869789   2018869789239900          2399                       0
# 1   2015664356   2015664356544100          5441                       0
# 2  20176005213  20176005213239901          2399                       1
# 3  20196012240  20196012240230800          2308                       0
# 4   2018861883   2018861883501600          5016                       0
#
#                   OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  FIRST_OCCURRENCE_DATE  \
# 0                     theft-other             larceny  12/27/2018 3:58:00 PM
# 1                traffic-accident    traffic-accident  11/13/2015 7:45:00 AM
# 2                   theft-bicycle             larceny    6/8/2017 1:15:00 PM
# 3                 theft-from-bldg             larceny   12/7/2019 1:07:00 PM
# 4  violation-of-restraining-order    all-other-crimes  12/22/2018 8:15:00 PM
#
# ...

# %%
DV_crime_df.columns
# Out:
# Index(['INCIDENT_ID', 'OFFENSE_ID', 'OFFENSE_CODE', 'OFFENSE_CODE_EXTENSION',
#        'OFFENSE_TYPE_ID', 'OFFENSE_CATEGORY_ID', 'FIRST_OCCURRENCE_DATE',
#        'LAST_OCCURRENCE_DATE', 'REPORTED_DATE', 'INCIDENT_ADDRESS', 'GEO_X',
#        'GEO_Y', 'GEO_LON', 'GEO_LAT', 'DISTRICT_ID', 'PRECINCT_ID',
#        'NEIGHBORHOOD_ID', 'IS_CRIME', 'IS_TRAFFIC'],
#       dtype='object')

# %%
DV_crime_df = DV_crime_df.loc[:, ["INCIDENT_ID", "OFFENSE_TYPE_ID", "OFFENSE_CATEGORY_ID", "GEO_LON", "GEO_LAT"]]

# %%
DV_crime_df.head()
# Out:
#    INCIDENT_ID                 OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# 0   2018869789                     theft-other             larceny
# 1   2015664356                traffic-accident    traffic-accident
# 2  20176005213                   theft-bicycle             larceny
# 3  20196012240                 theft-from-bldg             larceny
# 4   2018861883  violation-of-restraining-order    all-other-crimes
#
#       GEO_LON    GEO_LAT
# 0 -104.866156  39.755561
# 1 -105.040760  39.739991
# 2 -104.999264  39.753669
# 3 -105.029208  39.738134
# 4 -104.828868  39.797750

# %%
DV_crime_df.dtypes
# Out:
# INCIDENT_ID              int64
# OFFENSE_TYPE_ID         object
# OFFENSE_CATEGORY_ID     object
# GEO_LON                float64
# GEO_LAT                float64
# dtype: object

# %%
SF_crime_df = pd.read_csv("../Violence_data/SF_crime.csv")
SF_crime_df.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
SF_crime_df = SF_crime_df.loc[:, ["IncidntNum", "Category","Descript", "X", "Y"]]

# %%
SF_crime_df.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             X          Y
# 0 -122.403405  37.775421
# 1 -122.403405  37.775421
# 2 -122.388856  37.729981
# 3 -122.412971  37.785788
# 4 -122.419672  37.765050

# %%
SF_crime_df.dtypes
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# X             float64
# Y             float64
# dtype: object

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:1379@localhost:5432/project_2

# %%
# %sql CREATE TABLE SF_crime (IncidntNum int, Category varchar(200), descript varchar(200), X float, Y float);
# Out:
#  * postgresql://postgres:***@localhost:5432/project_2
# (psycopg2.errors.DuplicateTable) relation "sf_crime" already exists
#
# [SQL: CREATE TABLE SF_crime (IncidntNum int, Category varchar(200), descript varchar(200), X float, Y float);]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql CREATE TABLE DV_crime (INCIDENT_ID int, OFFENSE_TYPE_ID varchar(200), OFFENSE_CATEGORY_ID varchar(200), GEO_LON float, GEO_LAT float);
# Out:
#  * postgresql://postgres:***@localhost:5432/project_2
# (psycopg2.errors.DuplicateTable) relation "dv_crime" already exists
#
# [SQL: CREATE TABLE DV_crime (INCIDENT_ID int, OFFENSE_TYPE_ID varchar(200), OFFENSE_CATEGORY_ID varchar(200), GEO_LON float, GEO_LAT float);]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
DV_crime_df.OFFENSE_CATEGORY_ID = DV_crime_df.OFFENSE_CATEGORY_ID.astype(str)
DV_crime_df.OFFENSE_TYPE_ID = DV_crime_df.OFFENSE_TYPE_ID.astype(str)
SF_crime_df.Category = SF_crime_df.Category.astype(str)
SF_crime_df.Descript = SF_crime_df.Descript.astype(str)


SF_crime_df.to_csv("sf_data.csv", index = False)

# %%
DV_crime_df.to_csv("dv_data.csv", index = False)
